# %%
"""
Main File
numpy-matplotlib
Learning how to use Pandas, Matplotlib and Numpy
in a learning enviorment
"""

import pandas as pd
import matplotlib as mat
import numpy as np

data = pd.read_csv('../../data/Electric_Vehicle_Population_Data.csv')

print(data)
# Out:
#         VIN (1-10)        County               City State  Postal Code  \
# 0       KM8K33AGXL          King            Seattle    WA      98103.0
# 1       1C4RJYB61N          King            Bothell    WA      98011.0
# 2       1C4RJYD61P        Yakima             Yakima    WA      98908.0
# 3       5YJ3E1EA7J          King           Kirkland    WA      98034.0
# 4       WBY7Z8C5XJ      Thurston            Olympia    WA      98501.0
# ...            ...           ...                ...   ...          ...
# 150477  WBY43AW05P  Grays Harbor          Montesano    WA      98563.0
# 150478  5YJ3E1EB7P          King            Seattle    WA      98104.0
# 150479  5YJYGDEEXM          King            Seattle    WA      98109.0
# 150480  5UXTA6C08P     Snohomish  Mountlake Terrace    WA      98043.0
# 150481  7SAYGDEF8N        Skagit       Mount Vernon    WA      98273.0
#
#         Model Year     Make           Model  \
# 0             2020  HYUNDAI            KONA
# ...

# %% [markdown]
# ## Heads & Tails
# ```python
# data.head()
# data.tail()
# ```

# %%
data.head()
# Out:
#    VIN (1-10)    County      City State  Postal Code  Model Year     Make  \
# 0  KM8K33AGXL      King   Seattle    WA      98103.0        2020  HYUNDAI
# 1  1C4RJYB61N      King   Bothell    WA      98011.0        2022     JEEP
# 2  1C4RJYD61P    Yakima    Yakima    WA      98908.0        2023     JEEP
# 3  5YJ3E1EA7J      King  Kirkland    WA      98034.0        2018    TESLA
# 4  WBY7Z8C5XJ  Thurston   Olympia    WA      98501.0        2018      BMW
#
#             Model                   Electric Vehicle Type  \
# 0            KONA          Battery Electric Vehicle (BEV)
# 1  GRAND CHEROKEE  Plug-in Hybrid Electric Vehicle (PHEV)
# 2  GRAND CHEROKEE  Plug-in Hybrid Electric Vehicle (PHEV)
# 3         MODEL 3          Battery Electric Vehicle (BEV)
# 4              I3  Plug-in Hybrid Electric Vehicle (PHEV)
#
#   Clean Alternative Fuel Vehicle (CAFV) Eligibility  Electric Range  \
# 0           Clean Alternative Fuel Vehicle Eligible             258
# ...

# %%
data.tail()
# Out:
#         VIN (1-10)        County               City State  Postal Code  \
# 150477  WBY43AW05P  Grays Harbor          Montesano    WA      98563.0
# 150478  5YJ3E1EB7P          King            Seattle    WA      98104.0
# 150479  5YJYGDEEXM          King            Seattle    WA      98109.0
# 150480  5UXTA6C08P     Snohomish  Mountlake Terrace    WA      98043.0
# 150481  7SAYGDEF8N        Skagit       Mount Vernon    WA      98273.0
#
#         Model Year   Make    Model                   Electric Vehicle Type  \
# 150477        2023    BMW       I4          Battery Electric Vehicle (BEV)
# 150478        2023  TESLA  MODEL 3          Battery Electric Vehicle (BEV)
# 150479        2021  TESLA  MODEL Y          Battery Electric Vehicle (BEV)
# 150480        2023    BMW       X5  Plug-in Hybrid Electric Vehicle (PHEV)
# 150481        2022  TESLA  MODEL Y          Battery Electric Vehicle (BEV)
#
#         Clean Alternative Fuel Vehicle (CAFV) Eligibility  Electric Range  \
# ...

# %% [markdown]
# ## Checking Column Types
# ```python
# data.dtypes
# ```

# %%
data.dtypes
# Out:
# VIN (1-10)                                            object
# County                                                object
# City                                                  object
# State                                                 object
# Postal Code                                          float64
# Model Year                                             int64
# Make                                                  object
# Model                                                 object
# Electric Vehicle Type                                 object
# Clean Alternative Fuel Vehicle (CAFV) Eligibility     object
# Electric Range                                         int64
# Base MSRP                                              int64
# Legislative District                                 float64
# DOL Vehicle ID                                         int64
# Vehicle Location                                      object
# ...

# %% [markdown]
# ## Shapes
#
# This will find how many rows and columns there are:
# (rows, col)
#
# ```python
#     data.shape
# ```

# %%
# Finds the shape of the dataset
data.shape
# Out:
# (150482, 17)

# %%
# Finds the Non Null values
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150482 entries, 0 to 150481
# Data columns (total 17 columns):
#  #   Column                                             Non-Null Count   Dtype
# ---  ------                                             --------------   -----
#  0   VIN (1-10)                                         150482 non-null  object
#  1   County                                             150479 non-null  object
#  2   City                                               150479 non-null  object
#  3   State                                              150482 non-null  object
#  4   Postal Code                                        150479 non-null  float64
#  5   Model Year                                         150482 non-null  int64
#  6   Make                                               150482 non-null  object
#  7   Model                                              150482 non-null  object
# ...

# %% [markdown]
# ## Slicing Material from the Dataset
#
# Use with square bracekts
#
# ```python
#     data[['Make', 'Model']].head()
# ```
#
# As a reminder that `head()` will show the data at the top

# %%
# Shows only Head
data[['Make', 'Model']].head()
# Out:
#       Make           Model
# 0  HYUNDAI            KONA
# 1     JEEP  GRAND CHEROKEE
# 2     JEEP  GRAND CHEROKEE
# 3    TESLA         MODEL 3
# 4      BMW              I3

# %%
# Shows only head and tails
data[['Make', 'Model']]
# Out:
#            Make           Model
# 0       HYUNDAI            KONA
# 1          JEEP  GRAND CHEROKEE
# 2          JEEP  GRAND CHEROKEE
# 3         TESLA         MODEL 3
# 4           BMW              I3
# ...         ...             ...
# 150477      BMW              I4
# 150478    TESLA         MODEL 3
# 150479    TESLA         MODEL Y
# 150480      BMW              X5
# 150481    TESLA         MODEL Y
#
# [150482 rows x 2 columns]

# %%
# Pandas Series 
data['Make'].head()
# Out:
# 0    HYUNDAI
# 1       JEEP
# 2       JEEP
# 3      TESLA
# 4        BMW
# Name: Make, dtype: object

# %%
# Panadas Dataframe
type(data[['Make']].head())
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# **!!You cannot select multiple collumns with a Series!!**
#
# ## Select
#
# This is taking the first 5 rows of your dataset
# ```python
#     data.loc[:, ['Make']].head()
# ```

# %%
data.loc[:, ['Make']].head()
# Out:
#       Make
# 0  HYUNDAI
# 1     JEEP
# 2     JEEP
# 3    TESLA
# 4      BMW

# %% [markdown]
# ## filtering
#
# | Comparison Operator | Meaning |
# |---------------------|---------|
# | < | Less than |
# | <= | Less than or Equal to |
# | > | Greater than |
# | >= | Greater than or Equal to |
# | == | Equal to |
# | != | Not Equal |

# %%
data['Model'].value_counts()
# Out:
# MODEL Y        28502
# MODEL 3        27709
# LEAF           13187
# MODEL S         7611
# BOLT EV         5733
#                ...
# 745LE              2
# 918                1
# FLYING SPUR        1
# S-10 PICKUP        1
# BENTAYGA           1
# Name: Model, Length: 127, dtype: int64

# %%
make = data['Make']=='TESLA'

# %%
make.head()
# Out:
# 0    False
# 1    False
# 2    False
# 3     True
# 4    False
# Name: Make, dtype: bool

# %%
data[make].head()
# Out:
#    VIN (1-10)     County         City State  Postal Code  Model Year   Make  \
# 3  5YJ3E1EA7J       King     Kirkland    WA      98034.0        2018  TESLA
# 5  5YJ3E1EAXL  Snohomish   Marysville    WA      98271.0        2020  TESLA
# 7  5YJYGDEE3L       King  Woodinville    WA      98072.0        2020  TESLA
# 8  5YJ3E1EA1J     Island   Coupeville    WA      98239.0        2018  TESLA
# 9  7SAYGDEF0P       King     Bellevue    WA      98004.0        2023  TESLA
#
#      Model           Electric Vehicle Type  \
# 3  MODEL 3  Battery Electric Vehicle (BEV)
# 5  MODEL 3  Battery Electric Vehicle (BEV)
# 7  MODEL Y  Battery Electric Vehicle (BEV)
# 8  MODEL 3  Battery Electric Vehicle (BEV)
# 9  MODEL Y  Battery Electric Vehicle (BEV)
#
#    Clean Alternative Fuel Vehicle (CAFV) Eligibility  Electric Range  \
# 3            Clean Alternative Fuel Vehicle Eligible             215
# 5            Clean Alternative Fuel Vehicle Eligible             266
# ...

# %%
# Will show all of the collumns
# Reassigning the data variable
data = data.loc[make, :]

# %%
# data[make].value_counts()
data['Make'].value_counts()
# Out:
# TESLA    68983
# Name: Make, dtype: int64

# %%
filtered_year = data['Model Year'] > 2020

# %%
# Shows the filtered table of Tesla Cars later 
# than 2019 or same year or later than 2020.
# Shows all data
data.loc[filtered_year, :]
# Out:
#         VIN (1-10)  County          City State  Postal Code  Model Year  \
# 9       7SAYGDEF0P    King      Bellevue    WA      98004.0        2023
# 34      5YJ3E1EA4P    King      Bellevue    WA      98006.0        2023
# 54      7SAYGDEE7P    King        Renton    WA      98058.0        2023
# 74      5YJ3E1EA4P  Kitsap       Poulsbo    WA      98370.0        2023
# 92      5YJ3E1EA9P    King      Kirkland    WA      98034.0        2023
# ...            ...     ...           ...   ...          ...         ...
# 150472  5YJYGDEE2M    King     Fall City    WA      98024.0        2021
# 150474  5YJ3E1EA2N    King       Seattle    WA      98122.0        2022
# 150478  5YJ3E1EB7P    King       Seattle    WA      98104.0        2023
# 150479  5YJYGDEEXM    King       Seattle    WA      98109.0        2021
# 150481  7SAYGDEF8N  Skagit  Mount Vernon    WA      98273.0        2022
#
#          Make    Model           Electric Vehicle Type  \
# ...

# %%
data_year = data.loc[filtered_year, :]

# %%
data_year['Model Year'].value_counts(dropna=False)
# Out:
# 2023    17968
# 2022    13985
# 2021    11132
# Name: Model Year, dtype: int64

# %%
data.loc[make & filtered_year, :]
# Out:
#         VIN (1-10)  County          City State  Postal Code  Model Year  \
# 9       7SAYGDEF0P    King      Bellevue    WA      98004.0        2023
# 34      5YJ3E1EA4P    King      Bellevue    WA      98006.0        2023
# 54      7SAYGDEE7P    King        Renton    WA      98058.0        2023
# 74      5YJ3E1EA4P  Kitsap       Poulsbo    WA      98370.0        2023
# 92      5YJ3E1EA9P    King      Kirkland    WA      98034.0        2023
# ...            ...     ...           ...   ...          ...         ...
# 150472  5YJYGDEE2M    King     Fall City    WA      98024.0        2021
# 150474  5YJ3E1EA2N    King       Seattle    WA      98122.0        2022
# 150478  5YJ3E1EB7P    King       Seattle    WA      98104.0        2023
# 150479  5YJYGDEEXM    King       Seattle    WA      98109.0        2021
# 150481  7SAYGDEF8N  Skagit  Mount Vernon    WA      98273.0        2022
#
#          Make    Model           Electric Vehicle Type  \
# ...
