# %%
print('hello world')
# Out:
# hello world

# %%
import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array([1, 2, 3, 4, 5, 6, 7, 8])
ypoints = np.array([3, 8, 1, 10, 32, 50, 78, 90])

plt.plot(xpoints, ypoints)
plt.show()
